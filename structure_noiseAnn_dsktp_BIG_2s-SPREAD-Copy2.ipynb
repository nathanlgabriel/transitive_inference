# %%
import random
import numpy as np
import time
import numba
import math
from numpy.random import Generator, PCG64DXSM, SeedSequence
import multiprocessing as mp
from structure2_BIG_FNs_00 import play_sequence

np.set_printoptions(suppress=True)

# %%
# use this cell for setting initial perameters

# rng = np.random.default_rng()

sides = 2
pairs = np.asarray([[0, 1], [1, 0], [1, 2], [2, 1], [2, 3], [3, 2], [3, 4], [4, 3]])
testpairs = np.asarray([[1, 3], [3, 1]])
nonadjpairs = np.asarray([[0, 2], [2, 0], [0, 3], [3, 0], [0, 4], [4, 0], [1, 4], [4, 1], [2, 4], [4, 2]])
allpairs = np.concatenate((pairs, nonadjpairs, testpairs))

plen = len(pairs)
alen = len(allpairs)

terms = 5
# maxvalue = 10
startstop = 2
# noise = 0.2
annealing = 0.000003

timesteps = 6*10**7
runs = 100

# rein1 = 4
# rein2 = 0
# punish1 = 0
# punish2 = -8
inertia = 1

nsteps = 100
# blocklength = nsteps*10

# %%
# use this cell for running the code

#measuring how long code takes to run
start = time.perf_counter()



#nprocs = mp.cpu_count()-1
pool = mp.Pool(processes=25)

sg = SeedSequence()
rgs = [Generator(PCG64DXSM(s)) for s in sg.spawn(runs)]


for blocklength in [1000, 10000]:
    for maxvalue in [5, 10, 15, 20]:
        for noise in [0., .2]:
            for rein1 in range(2, 9, 2):
                for rein2 in range(0, 9, 2):
                    for punish1 in range(0, -9, -2):
                        for punish2 in range(0, -21, -2):
                            
                            mpseq_final = pool.starmap(play_sequence, [(n, rgs[n], rein1, punish1, rein2, punish2, timesteps, nsteps, sides, pairs, testpairs, nonadjpairs, allpairs, plen, alen, terms, maxvalue, startstop, noise, annealing, runs, inertia, blocklength) for n in range(runs)])

                            final_sigweights = []
                            final_cumsuc = []
                            final_cumsucadd = []
                            final_testcumsucadd = []
                            final_recweights = []

                            for res_idx in range(0, len(mpseq_final)):

                                final_sigweights.append(mpseq_final[res_idx][0])
                                final_cumsuc.append(mpseq_final[res_idx][1])
                                final_cumsucadd.append(mpseq_final[res_idx][2])
                                final_testcumsucadd.append(mpseq_final[res_idx][3])
                                final_recweights.append(mpseq_final[res_idx][4])

                            final_sigweights = np.asarray(final_sigweights)
                            final_cumsuc = np.asarray(final_cumsuc)
                            final_cumsucadd = np.asarray(final_cumsucadd)
                            final_testcumsucadd = np.asarray(final_testcumsucadd)
                            final_recweights = np.asarray(final_recweights)
                            
                            
                            print("average final cumsucadd = ")
                            print(np.average(final_cumsucadd)/(100))
                            # print(" ")

                            print("average test cumsum = ")
                            print(np.average(final_testcumsucadd)/(100))
                        
                            print(f'rein1 = {rein1} rein2 = {rein2} punish1 = {punish1} punish2 = {punish2}')
                            print(f'blocklengh = {blocklength} maxvalue = {maxvalue} noise = {noise}')
                            
                            print(" ")
                            print(" ")

finish = time.perf_counter()
print(f'Finished in {round(finish-start,0)/60} minutes')
# Out:
# average final cumsucadd =
# 0.6408
# average test cumsum =
# 0.5304
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7070000000000001
# average test cumsum =
# 0.7559999999999999
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7121999999999999
# average test cumsum =
# 0.7176
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6992
# average test cumsum =
# 0.6955
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6831
# average test cumsum =
# 0.6790999999999999
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6674
# average test cumsum =
# 0.6629
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.631
# average test cumsum =
# 0.6258
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6041
# average test cumsum =
# 0.6204999999999999
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.586
# average test cumsum =
# 0.6112
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5654
# average test cumsum =
# 0.6137
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5638000000000001
# average test cumsum =
# 0.613
# rein1 = 2 rein2 = 0 punish1 = 0 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7172
# average test cumsum =
# 0.6698000000000001
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7418
# average test cumsum =
# 0.8061
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7308
# average test cumsum =
# 0.8365
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7208
# average test cumsum =
# 0.8243
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6838
# average test cumsum =
# 0.8066
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6423000000000001
# average test cumsum =
# 0.8019
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6111
# average test cumsum =
# 0.7939
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6123
# average test cumsum =
# 0.7843000000000001
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5876
# average test cumsum =
# 0.7816
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5785
# average test cumsum =
# 0.7841
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5746
# average test cumsum =
# 0.7759
# rein1 = 2 rein2 = 0 punish1 = -2 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7182999999999999
# average test cumsum =
# 0.8009000000000001
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6995
# average test cumsum =
# 0.8286
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6890999999999999
# average test cumsum =
# 0.8286
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6762
# average test cumsum =
# 0.8308
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6423000000000001
# average test cumsum =
# 0.8127
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6303
# average test cumsum =
# 0.8229000000000001
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6214999999999999
# average test cumsum =
# 0.8223
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6147
# average test cumsum =
# 0.8140999999999999
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5906
# average test cumsum =
# 0.7993000000000001
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5891
# average test cumsum =
# 0.7928000000000001
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5831000000000001
# average test cumsum =
# 0.8073999999999999
# rein1 = 2 rein2 = 0 punish1 = -4 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6814
# average test cumsum =
# 0.7725
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6709999999999999
# average test cumsum =
# 0.7791
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6267
# average test cumsum =
# 0.7598999999999999
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6151
# average test cumsum =
# 0.7637
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6133
# average test cumsum =
# 0.752
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6096
# average test cumsum =
# 0.7615999999999999
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.585
# average test cumsum =
# 0.7576999999999999
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5874
# average test cumsum =
# 0.7483
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5907
# average test cumsum =
# 0.7535
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5821999999999999
# average test cumsum =
# 0.7517
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5722
# average test cumsum =
# 0.735
# rein1 = 2 rein2 = 0 punish1 = -6 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6502
# average test cumsum =
# 0.7703
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6227
# average test cumsum =
# 0.7547
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5989
# average test cumsum =
# 0.7448999999999999
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5954999999999999
# average test cumsum =
# 0.7719
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5924
# average test cumsum =
# 0.7445
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5893
# average test cumsum =
# 0.7443000000000001
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.579
# average test cumsum =
# 0.7448
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
# average final cumsucadd =
# 0.5777
# average test cumsum =
# 0.7258
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5807
# average test cumsum =
# 0.7354
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5863
# average test cumsum =
# 0.7415
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5767
# average test cumsum =
# 0.7387
# rein1 = 2 rein2 = 0 punish1 = -8 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6437
# average test cumsum =
# 0.5275
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6714
# average test cumsum =
# 0.6063000000000001
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7195999999999999
# average test cumsum =
# 0.7045999999999999
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.73
# average test cumsum =
# 0.7392
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7245999999999999
# average test cumsum =
# 0.7301000000000001
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7170000000000001
# average test cumsum =
# 0.7243999999999999
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6939
# average test cumsum =
# 0.6715000000000001
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6845
# average test cumsum =
# 0.6693000000000001
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6720999999999999
# average test cumsum =
# 0.6898000000000001
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6607
# average test cumsum =
# 0.6442
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6541
# average test cumsum =
# 0.6544
# rein1 = 2 rein2 = 2 punish1 = 0 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6670999999999999
# average test cumsum =
# 0.5770000000000001
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7138
# average test cumsum =
# 0.6843
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7373999999999999
# average test cumsum =
# 0.8011
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7397
# average test cumsum =
# 0.8064
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7342
# average test cumsum =
# 0.8144
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7204
# average test cumsum =
# 0.8139
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7123
# average test cumsum =
# 0.8138
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7162000000000001
# average test cumsum =
# 0.8095
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6977
# average test cumsum =
# 0.787
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6942
# average test cumsum =
# 0.7940999999999999
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6729999999999999
# average test cumsum =
# 0.8020999999999999
# rein1 = 2 rein2 = 2 punish1 = -2 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7121
# average test cumsum =
# 0.7127
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7345999999999999
# average test cumsum =
# 0.8245
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7147
# average test cumsum =
# 0.8107
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7120000000000001
# average test cumsum =
# 0.8176000000000001
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6916
# average test cumsum =
# 0.8183
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6865000000000001
# average test cumsum =
# 0.8056
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6855
# average test cumsum =
# 0.8207
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6811
# average test cumsum =
# 0.8131999999999999
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6744
# average test cumsum =
# 0.8169
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6625
# average test cumsum =
# 0.8154
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6522
# average test cumsum =
# 0.7918999999999999
# rein1 = 2 rein2 = 2 punish1 = -4 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7114
# average test cumsum =
# 0.7548
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7239
# average test cumsum =
# 0.7963
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7019
# average test cumsum =
# 0.8053
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6937000000000001
# average test cumsum =
# 0.7842
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6686
# average test cumsum =
# 0.7857999999999999
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6568999999999999
# average test cumsum =
# 0.7676000000000001
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6378
# average test cumsum =
# 0.757
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6423000000000001
# average test cumsum =
# 0.7755
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6249
# average test cumsum =
# 0.7631999999999999
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6174000000000001
# average test cumsum =
# 0.7436
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.613
# average test cumsum =
# 0.7240000000000001
# rein1 = 2 rein2 = 2 punish1 = -6 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7018000000000001
# average test cumsum =
# 0.7835
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7376999999999999
# average test cumsum =
# 0.7995
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
# average final cumsucadd =
# 0.7091
# average test cumsum =
# 0.7928000000000001
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6840999999999999
# average test cumsum =
# 0.7761
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6575
# average test cumsum =
# 0.7794
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.633
# average test cumsum =
# 0.7489
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.626
# average test cumsum =
# 0.7555
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6126
# average test cumsum =
# 0.7495
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6088
# average test cumsum =
# 0.7424
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.5928
# average test cumsum =
# 0.7236
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.595
# average test cumsum =
# 0.7283
# rein1 = 2 rein2 = 2 punish1 = -8 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6469
# average test cumsum =
# 0.5268
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6594
# average test cumsum =
# 0.5729
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6883
# average test cumsum =
# 0.6372
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7177
# average test cumsum =
# 0.722
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7339
# average test cumsum =
# 0.7701
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7368000000000001
# average test cumsum =
# 0.7789
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7241
# average test cumsum =
# 0.7595999999999999
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7162000000000001
# average test cumsum =
# 0.7156999999999999
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7145
# average test cumsum =
# 0.6970999999999999
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7068000000000001
# average test cumsum =
# 0.7053
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7056
# average test cumsum =
# 0.7089
# rein1 = 2 rein2 = 4 punish1 = 0 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6563
# average test cumsum =
# 0.5705
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6838
# average test cumsum =
# 0.5951
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7139
# average test cumsum =
# 0.6777
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.742
# average test cumsum =
# 0.7864
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7356
# average test cumsum =
# 0.779
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7509999999999999
# average test cumsum =
# 0.7956
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7323999999999999
# average test cumsum =
# 0.8231999999999999
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7302
# average test cumsum =
# 0.7889
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7256
# average test cumsum =
# 0.8004000000000001
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7188
# average test cumsum =
# 0.8019
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7156
# average test cumsum =
# 0.8062999999999999
# rein1 = 2 rein2 = 4 punish1 = -2 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6781
# average test cumsum =
# 0.6214
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7167
# average test cumsum =
# 0.7136
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7283
# average test cumsum =
# 0.7974
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7284999999999999
# average test cumsum =
# 0.8256999999999999
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7343999999999999
# average test cumsum =
# 0.8216
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7184999999999999
# average test cumsum =
# 0.8004000000000001
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7206
# average test cumsum =
# 0.8190999999999999
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6943
# average test cumsum =
# 0.8
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7
# average test cumsum =
# 0.8140000000000001
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.687
# average test cumsum =
# 0.7929
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6907
# average test cumsum =
# 0.7959999999999999
# rein1 = 2 rein2 = 4 punish1 = -4 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.693
# average test cumsum =
# 0.7001999999999999
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7192000000000001
# average test cumsum =
# 0.7879
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7254
# average test cumsum =
# 0.8134999999999999
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7153
# average test cumsum =
# 0.7777
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7073
# average test cumsum =
# 0.7988
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7131000000000001
# average test cumsum =
# 0.8136
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.695
# average test cumsum =
# 0.7981
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6738
# average test cumsum =
# 0.7879
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6806
# average test cumsum =
# 0.7873
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
# average final cumsucadd =
# 0.6613
# average test cumsum =
# 0.7831999999999999
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6587000000000001
# average test cumsum =
# 0.7733
# rein1 = 2 rein2 = 4 punish1 = -6 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7240000000000001
# average test cumsum =
# 0.7714
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7336
# average test cumsum =
# 0.7829
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7381
# average test cumsum =
# 0.821
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7326
# average test cumsum =
# 0.8129000000000001
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7171
# average test cumsum =
# 0.8218000000000001
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7076
# average test cumsum =
# 0.7903
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6938
# average test cumsum =
# 0.8076000000000001
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6755
# average test cumsum =
# 0.7825
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6712
# average test cumsum =
# 0.7768
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6542
# average test cumsum =
# 0.7873
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6494
# average test cumsum =
# 0.7773
# rein1 = 2 rein2 = 4 punish1 = -8 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6503
# average test cumsum =
# 0.5295000000000001
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.655
# average test cumsum =
# 0.5545
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6754000000000001
# average test cumsum =
# 0.5999
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6970000000000001
# average test cumsum =
# 0.6581999999999999
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7261
# average test cumsum =
# 0.6894
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7328
# average test cumsum =
# 0.7587999999999999
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7356999999999999
# average test cumsum =
# 0.7522
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7403
# average test cumsum =
# 0.7469
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7309
# average test cumsum =
# 0.7694
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7369
# average test cumsum =
# 0.7459
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7290000000000001
# average test cumsum =
# 0.7424
# rein1 = 2 rein2 = 6 punish1 = 0 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6501
# average test cumsum =
# 0.5642
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6704000000000001
# average test cumsum =
# 0.5751
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6897
# average test cumsum =
# 0.6098
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7182999999999999
# average test cumsum =
# 0.6516
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7338
# average test cumsum =
# 0.7676999999999999
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7434000000000001
# average test cumsum =
# 0.7813
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7440000000000001
# average test cumsum =
# 0.7923
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7514
# average test cumsum =
# 0.8168000000000001
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7339
# average test cumsum =
# 0.8159000000000001
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7354999999999999
# average test cumsum =
# 0.8048000000000001
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7245
# average test cumsum =
# 0.8068000000000001
# rein1 = 2 rein2 = 6 punish1 = -2 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6631999999999999
# average test cumsum =
# 0.6038
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6912999999999999
# average test cumsum =
# 0.6238
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.718
# average test cumsum =
# 0.7178
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7306
# average test cumsum =
# 0.8119
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7367
# average test cumsum =
# 0.8068000000000001
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7361
# average test cumsum =
# 0.7956
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7392
# average test cumsum =
# 0.8301999999999999
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7278
# average test cumsum =
# 0.8218000000000001
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7265999999999999
# average test cumsum =
# 0.8301000000000001
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7129000000000001
# average test cumsum =
# 0.8234
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7127
# average test cumsum =
# 0.8116
# rein1 = 2 rein2 = 6 punish1 = -4 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6668999999999999
# average test cumsum =
# 0.5985
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7018000000000001
# average test cumsum =
# 0.7139
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.711
# average test cumsum =
# 0.7498
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.731
# average test cumsum =
# 0.7894
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
# average final cumsucadd =
# 0.7273999999999999
# average test cumsum =
# 0.7998999999999999
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7217
# average test cumsum =
# 0.8147
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7115
# average test cumsum =
# 0.772
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7111
# average test cumsum =
# 0.7970999999999999
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6986
# average test cumsum =
# 0.8027
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.69
# average test cumsum =
# 0.7974
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6851999999999999
# average test cumsum =
# 0.7927
# rein1 = 2 rein2 = 6 punish1 = -6 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7117
# average test cumsum =
# 0.7156
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.725
# average test cumsum =
# 0.7955
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7291
# average test cumsum =
# 0.7972
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7342
# average test cumsum =
# 0.7993000000000001
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7395999999999999
# average test cumsum =
# 0.841
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7306999999999999
# average test cumsum =
# 0.8345
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7251000000000001
# average test cumsum =
# 0.8301999999999999
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7198
# average test cumsum =
# 0.826
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7090000000000001
# average test cumsum =
# 0.7948999999999999
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6953
# average test cumsum =
# 0.7970999999999999
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6944
# average test cumsum =
# 0.802
# rein1 = 2 rein2 = 6 punish1 = -8 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6505
# average test cumsum =
# 0.5303
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6474
# average test cumsum =
# 0.5438000000000001
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6655
# average test cumsum =
# 0.5747
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6888
# average test cumsum =
# 0.6156
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6966
# average test cumsum =
# 0.6384000000000001
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7218000000000001
# average test cumsum =
# 0.7192000000000001
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7413
# average test cumsum =
# 0.7753
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7372
# average test cumsum =
# 0.7515999999999999
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7353000000000001
# average test cumsum =
# 0.7687999999999999
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7403
# average test cumsum =
# 0.7602
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7336
# average test cumsum =
# 0.7576999999999999
# rein1 = 2 rein2 = 8 punish1 = 0 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6468
# average test cumsum =
# 0.5649000000000001
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6635
# average test cumsum =
# 0.5674
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6857
# average test cumsum =
# 0.5857
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6919
# average test cumsum =
# 0.6022
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7214
# average test cumsum =
# 0.6951
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7304
# average test cumsum =
# 0.7608
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7458
# average test cumsum =
# 0.7807999999999999
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7382
# average test cumsum =
# 0.7759
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7473000000000001
# average test cumsum =
# 0.8087000000000001
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7404999999999999
# average test cumsum =
# 0.8067
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.736
# average test cumsum =
# 0.823
# rein1 = 2 rein2 = 8 punish1 = -2 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6602
# average test cumsum =
# 0.5902000000000001
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6731999999999999
# average test cumsum =
# 0.6096
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6918000000000001
# average test cumsum =
# 0.6323
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7156999999999999
# average test cumsum =
# 0.7112
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7252
# average test cumsum =
# 0.7542
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7339
# average test cumsum =
# 0.8109999999999999
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7358
# average test cumsum =
# 0.8112
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7381
# average test cumsum =
# 0.7951999999999999
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.743
# average test cumsum =
# 0.8111
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7315
# average test cumsum =
# 0.8172
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
# average final cumsucadd =
# 0.7217
# average test cumsum =
# 0.8217
# rein1 = 2 rein2 = 8 punish1 = -4 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6551
# average test cumsum =
# 0.5866
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6746
# average test cumsum =
# 0.5885
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7014
# average test cumsum =
# 0.7
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.718
# average test cumsum =
# 0.7042
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7228
# average test cumsum =
# 0.7777
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7304999999999999
# average test cumsum =
# 0.8026000000000001
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7206999999999999
# average test cumsum =
# 0.7737
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7258
# average test cumsum =
# 0.7934
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7215
# average test cumsum =
# 0.7918000000000001
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7178
# average test cumsum =
# 0.7916
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7114
# average test cumsum =
# 0.7831999999999999
# rein1 = 2 rein2 = 8 punish1 = -6 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6827
# average test cumsum =
# 0.6184000000000001
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7051999999999999
# average test cumsum =
# 0.6557999999999999
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7229000000000001
# average test cumsum =
# 0.7526
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7394
# average test cumsum =
# 0.7859
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.732
# average test cumsum =
# 0.7526
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7359
# average test cumsum =
# 0.7956
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7306
# average test cumsum =
# 0.8137000000000001
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7306
# average test cumsum =
# 0.8216
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7216
# average test cumsum =
# 0.8231
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7282
# average test cumsum =
# 0.8267
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7132
# average test cumsum =
# 0.7748999999999999
# rein1 = 2 rein2 = 8 punish1 = -8 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6397999999999999
# average test cumsum =
# 0.5075
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6686
# average test cumsum =
# 0.5732
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7099
# average test cumsum =
# 0.7412000000000001
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7179000000000001
# average test cumsum =
# 0.7692
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7116
# average test cumsum =
# 0.7436
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7038
# average test cumsum =
# 0.7241
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6918000000000001
# average test cumsum =
# 0.6951999999999999
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -12
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6848000000000001
# average test cumsum =
# 0.6943
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -14
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6799
# average test cumsum =
# 0.6820999999999999
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -16
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6703
# average test cumsum =
# 0.6787000000000001
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -18
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6511
# average test cumsum =
# 0.674
# rein1 = 4 rein2 = 0 punish1 = 0 punish2 = -20
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.6664
# average test cumsum =
# 0.5448
# rein1 = 4 rein2 = 0 punish1 = -2 punish2 = 0
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7134999999999999
# average test cumsum =
# 0.6797
# rein1 = 4 rein2 = 0 punish1 = -2 punish2 = -2
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7295
# average test cumsum =
# 0.8028
# rein1 = 4 rein2 = 0 punish1 = -2 punish2 = -4
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7256999999999999
# average test cumsum =
# 0.7992
# rein1 = 4 rein2 = 0 punish1 = -2 punish2 = -6
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7148
# average test cumsum =
# 0.8107
# rein1 = 4 rein2 = 0 punish1 = -2 punish2 = -8
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7236
# average test cumsum =
# 0.8129000000000001
# rein1 = 4 rein2 = 0 punish1 = -2 punish2 = -10
# blocklengh = 1000 maxvalue = 5 noise = 0.0
#
#
# average final cumsucadd =
# 0.7132999999999999
# average test cumsum =
# ...
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
# Traceback (most recent call last):
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# KeyboardInterrupt
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
# KeyboardInterrupt
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 174, in randoms
#     frandunif4 = frng.random((fnsteps1, fmaxvalue1))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 171, in randoms
#     fnaturesides1 = frng.integers(fsides1, size=(fnsteps1, 2))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 171, in randoms
#     fnaturesides1 = frng.integers(fsides1, size=(fnsteps1, 2))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 238, in play_sequence
#     recweights, sigweights, cumsucadd = nstepsfn(noise, plen, alen, maxvalue, naturesides, recweights, sigweights, randunif2, randunif4, randunif6, randunif8, naturestates, nsteps, allpairs, rein, punish)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 171, in randoms
#     fnaturesides1 = frng.integers(fsides1, size=(fnsteps1, 2))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 170, in randoms
#     fnaturestates1 = frng.integers(fplen1*falen1, size=fnsteps1)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 170, in randoms
#     fnaturestates1 = frng.integers(fplen1*falen1, size=fnsteps1)
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 171, in randoms
#     fnaturesides1 = frng.integers(fsides1, size=(fnsteps1, 2))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 170, in randoms
#     fnaturestates1 = frng.integers(fplen1*falen1, size=fnsteps1)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 171, in randoms
#     fnaturesides1 = frng.integers(fsides1, size=(fnsteps1, 2))
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 170, in randoms
#     fnaturestates1 = frng.integers(fplen1*falen1, size=fnsteps1)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "_generator.pyx", line 540, in numpy.random._generator.Generator.integers
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "_generator.pyx", line 540, in numpy.random._generator.Generator.integers
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 171, in randoms
#     fnaturesides1 = frng.integers(fsides1, size=(fnsteps1, 2))
#   File "_generator.pyx", line 540, in numpy.random._generator.Generator.integers
# KeyboardInterrupt
#   File "_generator.pyx", line 540, in numpy.random._generator.Generator.integers
#   File "_bounded_integers.pyx", line 1228, in numpy.random._bounded_integers._rand_int64
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "_generator.pyx", line 540, in numpy.random._generator.Generator.integers
#   File "_bounded_integers.pyx", line 1228, in numpy.random._bounded_integers._rand_int64
#   File "_bounded_integers.pyx", line 1228, in numpy.random._bounded_integers._rand_int64
#   File "/home/nothin/miniconda3/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "_bounded_integers.pyx", line 1228, in numpy.random._bounded_integers._rand_int64
#   File "<__array_function__ internals>", line 5, in prod
#   File "_bounded_integers.pyx", line 1228, in numpy.random._bounded_integers._rand_int64
#   File "<__array_function__ internals>", line 2, in prod
#   File "<__array_function__ internals>", line 2, in prod
#   File "/home/nothin/miniconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 3051, in prod
#     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#   File "<__array_function__ internals>", line 5, in prod
#   File "<__array_function__ internals>", line 4, in prod
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 237, in play_sequence
#     naturestates, randunif2, randunif4, randunif6, randunif8, naturesides = randoms(rng, nsteps, maxvalue, plen, alen, sides)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/nothin/miniconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   File "/home/nothin/miniconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 3051, in prod
#     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#   File "/home/nothin/miniconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 2928, in _prod_dispatcher
#     def _prod_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#   File "/home/nothin/python/structure2/structure2_BIG_FNs_00.py", line 170, in randoms
#     fnaturestates1 = frng.integers(fplen1*falen1, size=fnsteps1)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "_generator.pyx", line 540, in numpy.random._generator.Generator.integers
#   File "/home/nothin/miniconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 69, in _wrapreduction
#     def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#   File "_bounded_integers.pyx", line 1228, in numpy.random._bounded_integers._rand_int64
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 5, in prod
#   File "/home/nothin/miniconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 3051, in prod
#     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#   File "/home/nothin/miniconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 76, in _wrapreduction
#     except AttributeError:
# KeyboardInterrupt

# %%
# np.save('structure_noiseAnn_dsktp_BIG_2s_sigweights_c2', final_sigweights)
# np.save('structure_noiseAnn_dsktp_BIG_2s_recweights_c2', final_recweights)

# %%
idxy = 2
sigweights = final_sigweights[idxy]
cumsucadd = final_cumsucadd[idxy]
testcumsucadd = final_testcumsucadd[idxy]
recweights = final_recweights[idxy]

print(cumsucadd)
print(testcumsucadd)
# Out:
# 87.0
# 75.0

# %%
simple_sig = np.zeros_like(sigweights)
for ax0 in range(0, sides):
    for ax1 in range(0, 2):
        for ax2 in range(0, terms):
            simplesum = sigweights[ax0, ax1, ax2][0]+sigweights[ax0, ax1, ax2][1]
            simple_sig[ax0, ax1, ax2][0] = math.floor(maxvalue*(sigweights[ax0, ax1, ax2][0] / simplesum))
            simple_sig[ax0, ax1, ax2][1] = math.floor(maxvalue*(sigweights[ax0, ax1, ax2][1] / simplesum))
            

print(simple_sig)
print(sigweights)

for s in range(0, sides):
    for l in range(0, terms):
        for s2 in range(0, sides):
            for r in range(0, terms):
                if l != r:
                    print(f'LEFT side: {s} term: {l} magnitude: {simple_sig[s, 0, l, 1]}')
                    print(f'RIGHT side: {s2} term: {r} magnitude: {simple_sig[s2, 1, r, 1]}')
                    print(f'receiver: {recweights[math.floor(simple_sig[s, 0, l, 1]*(maxvalue+1) + simple_sig[s2, 1, r, 1])]}')
# Out:
# [[[[14.  0.]
#    [ 8.  6.]
#    [ 0. 14.]
#    [ 0. 14.]
#    [12.  2.]]
#
#   [[ 4. 10.]
#    [ 6.  8.]
#    [ 7.  7.]
#    [ 0. 14.]
#    [ 0. 14.]]]
#
#
#  [[[14.  0.]
#    [ 7.  7.]
#    [ 0. 14.]
#    [ 0. 14.]
#    [10.  4.]]
#
#   [[ 5.  9.]
#    [ 6.  8.]
#    [ 7.  7.]
#    [ 0. 14.]
#    [ 0. 14.]]]]
# [[[[1.10386245e+08 1.57000000e+02]
#    [1.04100000e+03 7.01000000e+02]
#    [2.36762900e+06 2.22964593e+08]
#    [2.93013300e+06 2.31217229e+08]
#    [5.75310530e+07 1.03713690e+07]]
#
#   [[7.70000000e+01 1.65000000e+02]
#    [8.85465690e+07 1.14411833e+08]
#    [2.28217610e+07 2.34657210e+07]
#    [7.33836500e+06 1.22417337e+08]
#    [7.68747300e+06 1.20172709e+08]]]
#
#
#  [[[1.60832105e+08 1.00000000e+00]
#    [2.81000000e+02 2.61000000e+02]
#    [1.97664100e+06 1.86964081e+08]
#    [1.76934900e+06 1.88444933e+08]
#    [2.57000000e+02 1.05000000e+02]]
#
#   [[1.41000000e+02 2.21000000e+02]
#    [6.61931290e+07 8.28842530e+07]
#    [2.06726970e+07 2.10618650e+07]
#    [8.43535300e+06 1.34437249e+08]
#    [9.02287300e+06 1.38524029e+08]]]]
# LEFT side: 0 term: 0 magnitude: 0.0
# RIGHT side: 0 term: 1 magnitude: 8.0
# receiver: [      1. 3037494.]
# LEFT side: 0 term: 0 magnitude: 0.0
# RIGHT side: 0 term: 2 magnitude: 7.0
# receiver: [      1. 1918557.]
# LEFT side: 0 term: 0 magnitude: 0.0
# RIGHT side: 0 term: 3 magnitude: 14.0
# receiver: [      1. 4005862.]
# LEFT side: 0 term: 0 magnitude: 0.0
# RIGHT side: 0 term: 4 magnitude: 14.0
# receiver: [      1. 4005862.]
# LEFT side: 0 term: 0 magnitude: 0.0
# RIGHT side: 1 term: 1 magnitude: 8.0
# receiver: [      1. 3037494.]
# LEFT side: 0 term: 0 magnitude: 0.0
# RIGHT side: 1 term: 2 magnitude: 7.0
# receiver: [      1. 1918557.]
# LEFT side: 0 term: 0 magnitude: 0.0
# RIGHT side: 1 term: 3 magnitude: 14.0
# receiver: [      1. 4005862.]
# LEFT side: 0 term: 0 magnitude: 0.0
# RIGHT side: 1 term: 4 magnitude: 14.0
# receiver: [      1. 4005862.]
# LEFT side: 0 term: 1 magnitude: 6.0
# RIGHT side: 0 term: 0 magnitude: 10.0
# receiver: [ 1. 13.]
# LEFT side: 0 term: 1 magnitude: 6.0
# RIGHT side: 0 term: 2 magnitude: 7.0
# receiver: [354606.      1.]
# LEFT side: 0 term: 1 magnitude: 6.0
# RIGHT side: 0 term: 3 magnitude: 14.0
# receiver: [    1. 87861.]
# LEFT side: 0 term: 1 magnitude: 6.0
# RIGHT side: 0 term: 4 magnitude: 14.0
# receiver: [    1. 87861.]
# LEFT side: 0 term: 1 magnitude: 6.0
# RIGHT side: 1 term: 0 magnitude: 9.0
# receiver: [10. 10.]
# LEFT side: 0 term: 1 magnitude: 6.0
# RIGHT side: 1 term: 2 magnitude: 7.0
# receiver: [354606.      1.]
# LEFT side: 0 term: 1 magnitude: 6.0
# RIGHT side: 1 term: 3 magnitude: 14.0
# receiver: [    1. 87861.]
# LEFT side: 0 term: 1 magnitude: 6.0
# RIGHT side: 1 term: 4 magnitude: 14.0
# receiver: [    1. 87861.]
# LEFT side: 0 term: 2 magnitude: 14.0
# RIGHT side: 0 term: 0 magnitude: 10.0
# receiver: [6299765.       1.]
# LEFT side: 0 term: 2 magnitude: 14.0
# RIGHT side: 0 term: 1 magnitude: 8.0
# receiver: [3738785.       1.]
# LEFT side: 0 term: 2 magnitude: 14.0
# RIGHT side: 0 term: 3 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 0 term: 2 magnitude: 14.0
# RIGHT side: 0 term: 4 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 0 term: 2 magnitude: 14.0
# RIGHT side: 1 term: 0 magnitude: 9.0
# receiver: [5447493.       1.]
# LEFT side: 0 term: 2 magnitude: 14.0
# RIGHT side: 1 term: 1 magnitude: 8.0
# receiver: [3738785.       1.]
# LEFT side: 0 term: 2 magnitude: 14.0
# RIGHT side: 1 term: 3 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 0 term: 2 magnitude: 14.0
# RIGHT side: 1 term: 4 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 0 term: 3 magnitude: 14.0
# RIGHT side: 0 term: 0 magnitude: 10.0
# receiver: [6299765.       1.]
# LEFT side: 0 term: 3 magnitude: 14.0
# RIGHT side: 0 term: 1 magnitude: 8.0
# receiver: [3738785.       1.]
# LEFT side: 0 term: 3 magnitude: 14.0
# RIGHT side: 0 term: 2 magnitude: 7.0
# receiver: [1995141.       1.]
# LEFT side: 0 term: 3 magnitude: 14.0
# RIGHT side: 0 term: 4 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 0 term: 3 magnitude: 14.0
# RIGHT side: 1 term: 0 magnitude: 9.0
# receiver: [5447493.       1.]
# LEFT side: 0 term: 3 magnitude: 14.0
# RIGHT side: 1 term: 1 magnitude: 8.0
# receiver: [3738785.       1.]
# LEFT side: 0 term: 3 magnitude: 14.0
# RIGHT side: 1 term: 2 magnitude: 7.0
# receiver: [1995141.       1.]
# LEFT side: 0 term: 3 magnitude: 14.0
# RIGHT side: 1 term: 4 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 0 term: 4 magnitude: 2.0
# RIGHT side: 0 term: 0 magnitude: 10.0
# receiver: [    1. 20654.]
# LEFT side: 0 term: 4 magnitude: 2.0
# RIGHT side: 0 term: 1 magnitude: 8.0
# receiver: [    1. 68422.]
# LEFT side: 0 term: 4 magnitude: 2.0
# RIGHT side: 0 term: 2 magnitude: 7.0
# receiver: [104222.      1.]
# LEFT side: 0 term: 4 magnitude: 2.0
# RIGHT side: 0 term: 3 magnitude: 14.0
# receiver: [ 1. 22.]
# LEFT side: 0 term: 4 magnitude: 2.0
# RIGHT side: 1 term: 0 magnitude: 9.0
# receiver: [113721.      1.]
# LEFT side: 0 term: 4 magnitude: 2.0
# RIGHT side: 1 term: 1 magnitude: 8.0
# receiver: [    1. 68422.]
# LEFT side: 0 term: 4 magnitude: 2.0
# RIGHT side: 1 term: 2 magnitude: 7.0
# receiver: [104222.      1.]
# LEFT side: 0 term: 4 magnitude: 2.0
# RIGHT side: 1 term: 3 magnitude: 14.0
# receiver: [ 1. 22.]
# LEFT side: 1 term: 0 magnitude: 0.0
# RIGHT side: 0 term: 1 magnitude: 8.0
# receiver: [      1. 3037494.]
# LEFT side: 1 term: 0 magnitude: 0.0
# RIGHT side: 0 term: 2 magnitude: 7.0
# receiver: [      1. 1918557.]
# LEFT side: 1 term: 0 magnitude: 0.0
# RIGHT side: 0 term: 3 magnitude: 14.0
# receiver: [      1. 4005862.]
# LEFT side: 1 term: 0 magnitude: 0.0
# RIGHT side: 0 term: 4 magnitude: 14.0
# receiver: [      1. 4005862.]
# LEFT side: 1 term: 0 magnitude: 0.0
# RIGHT side: 1 term: 1 magnitude: 8.0
# receiver: [      1. 3037494.]
# LEFT side: 1 term: 0 magnitude: 0.0
# RIGHT side: 1 term: 2 magnitude: 7.0
# receiver: [      1. 1918557.]
# LEFT side: 1 term: 0 magnitude: 0.0
# RIGHT side: 1 term: 3 magnitude: 14.0
# receiver: [      1. 4005862.]
# LEFT side: 1 term: 0 magnitude: 0.0
# RIGHT side: 1 term: 4 magnitude: 14.0
# receiver: [      1. 4005862.]
# LEFT side: 1 term: 1 magnitude: 7.0
# RIGHT side: 0 term: 0 magnitude: 10.0
# receiver: [  1. 897.]
# LEFT side: 1 term: 1 magnitude: 7.0
# RIGHT side: 0 term: 2 magnitude: 7.0
# receiver: [     1. 579838.]
# LEFT side: 1 term: 1 magnitude: 7.0
# RIGHT side: 0 term: 3 magnitude: 14.0
# receiver: [     1. 192589.]
# LEFT side: 1 term: 1 magnitude: 7.0
# RIGHT side: 0 term: 4 magnitude: 14.0
# receiver: [     1. 192589.]
# LEFT side: 1 term: 1 magnitude: 7.0
# RIGHT side: 1 term: 0 magnitude: 9.0
# receiver: [ 1. 53.]
# LEFT side: 1 term: 1 magnitude: 7.0
# RIGHT side: 1 term: 2 magnitude: 7.0
# receiver: [     1. 579838.]
# LEFT side: 1 term: 1 magnitude: 7.0
# RIGHT side: 1 term: 3 magnitude: 14.0
# receiver: [     1. 192589.]
# LEFT side: 1 term: 1 magnitude: 7.0
# RIGHT side: 1 term: 4 magnitude: 14.0
# receiver: [     1. 192589.]
# LEFT side: 1 term: 2 magnitude: 14.0
# RIGHT side: 0 term: 0 magnitude: 10.0
# receiver: [6299765.       1.]
# LEFT side: 1 term: 2 magnitude: 14.0
# RIGHT side: 0 term: 1 magnitude: 8.0
# receiver: [3738785.       1.]
# LEFT side: 1 term: 2 magnitude: 14.0
# RIGHT side: 0 term: 3 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 1 term: 2 magnitude: 14.0
# RIGHT side: 0 term: 4 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 1 term: 2 magnitude: 14.0
# RIGHT side: 1 term: 0 magnitude: 9.0
# receiver: [5447493.       1.]
# LEFT side: 1 term: 2 magnitude: 14.0
# RIGHT side: 1 term: 1 magnitude: 8.0
# receiver: [3738785.       1.]
# LEFT side: 1 term: 2 magnitude: 14.0
# RIGHT side: 1 term: 3 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 1 term: 2 magnitude: 14.0
# RIGHT side: 1 term: 4 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 1 term: 3 magnitude: 14.0
# RIGHT side: 0 term: 0 magnitude: 10.0
# receiver: [6299765.       1.]
# LEFT side: 1 term: 3 magnitude: 14.0
# RIGHT side: 0 term: 1 magnitude: 8.0
# receiver: [3738785.       1.]
# LEFT side: 1 term: 3 magnitude: 14.0
# RIGHT side: 0 term: 2 magnitude: 7.0
# receiver: [1995141.       1.]
# LEFT side: 1 term: 3 magnitude: 14.0
# RIGHT side: 0 term: 4 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 1 term: 3 magnitude: 14.0
# RIGHT side: 1 term: 0 magnitude: 9.0
# receiver: [5447493.       1.]
# LEFT side: 1 term: 3 magnitude: 14.0
# RIGHT side: 1 term: 1 magnitude: 8.0
# receiver: [3738785.       1.]
# LEFT side: 1 term: 3 magnitude: 14.0
# RIGHT side: 1 term: 2 magnitude: 7.0
# receiver: [1995141.       1.]
# LEFT side: 1 term: 3 magnitude: 14.0
# RIGHT side: 1 term: 4 magnitude: 14.0
# receiver: [1317874.       1.]
# LEFT side: 1 term: 4 magnitude: 4.0
# RIGHT side: 0 term: 0 magnitude: 10.0
# receiver: [1965746.       1.]
# LEFT side: 1 term: 4 magnitude: 4.0
# RIGHT side: 0 term: 1 magnitude: 8.0
# receiver: [    1. 57746.]
# LEFT side: 1 term: 4 magnitude: 4.0
# RIGHT side: 0 term: 2 magnitude: 7.0
# receiver: [226822.      1.]
# LEFT side: 1 term: 4 magnitude: 4.0
# RIGHT side: 0 term: 3 magnitude: 14.0
# receiver: [   1. 4774.]
# LEFT side: 1 term: 4 magnitude: 4.0
# RIGHT side: 1 term: 0 magnitude: 9.0
# receiver: [280834.      1.]
# LEFT side: 1 term: 4 magnitude: 4.0
# RIGHT side: 1 term: 1 magnitude: 8.0
# receiver: [    1. 57746.]
# LEFT side: 1 term: 4 magnitude: 4.0
# RIGHT side: 1 term: 2 magnitude: 7.0
# receiver: [226822.      1.]
# LEFT side: 1 term: 4 magnitude: 4.0
# RIGHT side: 1 term: 3 magnitude: 14.0
# receiver: [   1. 4774.]
